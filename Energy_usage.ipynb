# %% [markdown]
# <a href="https://colab.research.google.com/github/ayomide2021/UK-Energy-Usage/blob/main/Energy_usage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline **

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  Get the Data

# %% [markdown]
# We'll work with the NEED csv file from Department for Energy Security and Netzero. It has 4 million properties data.
#
# ** Read in the NEED csv csv file as a DataFrame.**

# %%
df = pd.read_csv('anon2024_4million.csv')
df.head(10)
# Out:
#        PROP_TYPE  PROP_AGE_BAND  FLOOR_AREA_BAND  CONSERVATORY_FLAG  \
# 0           Flat              1                1                NaN
# 1           Flat              1                2                NaN
# 2  Semi detached              2                2                NaN
# 3    End terrace              3                2                NaN
# 4           Flat              4                1                0.0
# 5  Semi detached              3                2                NaN
# 6           Flat              4                1                0.0
# 7       Detached              4                4                0.0
# 8           Flat              1                2                NaN
# 9  Semi detached              4                2                NaN
#
#   COUNCIL_TAX_BAND  IMD_BAND_ENG  IMD_BAND_WALES     REGION     EPC  LI_FLAG  \
# 0                D           5.0             NaN  E12000007       D        0
# ...

# %%
df.shape
# Out:
# (1245506, 88)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1245506 entries, 0 to 1245505
# Data columns (total 88 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   PROP_TYPE          1245506 non-null  object
#  1   PROP_AGE_BAND      1245506 non-null  int64
#  2   FLOOR_AREA_BAND    1245506 non-null  int64
#  3   CONSERVATORY_FLAG  217681 non-null   float64
#  4   COUNCIL_TAX_BAND   1245506 non-null  object
#  5   IMD_BAND_ENG       1184453 non-null  float64
#  6   IMD_BAND_WALES     61053 non-null    float64
#  7   REGION             1245506 non-null  object
#  8   EPC                1245506 non-null  object
#  9   LI_FLAG            1245506 non-null  int64
#  10  LI_DATE            182630 non-null   float64
#  11  CWI_FLAG           1245506 non-null  int64
#  12  CWI_DATE           180813 non-null   float64
#  13  PV_FLAG            1245506 non-null  int64
#  14  PV_DATE            14985 non-null    float64
# ...
